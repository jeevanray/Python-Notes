# %%
import csv

with open('year2017.csv') as file_obj :
    file_data = csv.DictReader(file_obj, skipinitialspace = True)
    file_list = list(file_data) 

country_killed = {}
for row in file_list :
    key = row['Country']
    value = row['Killed']
    
    if value != '' :
        value = int(float(value))
    else :
        value = 0
        
    if key in country_killed :
        country_killed[key] += value
    else :
        country_killed[key] = 0
country_killed
# Out:
# {'Afghanistan': 6092,
#  'Sudan': 80,
#  'Democratic Republic of the Congo': 589,
#  'Turkey': 183,
#  'Syria': 2022,
#  'Pakistan': 1075,
#  'Italy': 0,
#  'Somalia': 1909,
#  'Yemen': 759,
#  'Bahrain': 5,
#  'Myanmar': 218,
#  'Burundi': 19,
#  'Iraq': 6467,
#  'Egypt': 877,
#  'Burkina Faso': 52,
#  'India': 465,
#  'Algeria': 11,
#  'United States': 95,
#  'Philippines': 496,
#  'Greece': 0,
#  'Mali': 361,
#  'Libya': 288,
#  'Central African Republic': 599,
#  'Nigeria': 1805,
#  'Lebanon': 17,
#  'Mexico': 22,
#  'Cameroon': 227,
#  'Ethiopia': 67,
#  'Kyrgyzstan': 0,
#  'Serbia': 0,
#  'Sweden': 5,
#  'Thailand': 71,
#  'Iran': 38,
#  'France': 7,
#  'United Kingdom': 42,
#  'West Bank and Gaza Strip': 45,
#  'Ukraine': 38,
#  'Paraguay': 2,
#  'Colombia': 83,
#  'Malaysia': 0,
#  'Russia': 61,
#  'Kosovo': 0,
#  'South Africa': 20,
#  'Chile': 0,
#  'Kenya': 126,
#  'Israel': 3,
#  'Saudi Arabia': 30,
#  'China': 16,
#  'Nepal': 4,
#  'Ecuador': 0,
#  'Niger': 146,
#  'Venezuela': 5,
#  'South Sudan': 571,
#  'Canada': 0,
#  'Bangladesh': 24,
#  'Tajikistan': 1,
#  'Angola': 7,
#  'Ireland': 0,
#  'Peru': 7,
#  'Dominican Republic': 0,
#  'Poland': 0,
#  'Jordan': 3,
#  'Azerbaijan': 0,
#  'Mozambique': 21,
#  'Indonesia': 19,
#  'Germany': 1,
#  'Brazil': 0,
#  'Macedonia': 0,
#  'Tunisia': 2,
#  'Uganda': 4,
#  'Chad': 62,
#  'Finland': 2,
#  'Australia': 3,
#  'Norway': 0,
#  'Vietnam': 0,
#  'Tanzania': 0,
#  'Sierra Leone': 0,
#  'Sri Lanka': 1,
#  'Maldives': 0,
#  'Belgium': 2,
#  'Rwanda': 1,
#  'Honduras': 0,
#  'Czech Republic': 0,
#  'Malta': 1,
#  'Gabon': 0,
#  'Laos': 0,
#  'Djibouti': 0,
#  'Austria': 0,
#  'Zambia': 0,
#  'Argentina': 0,
#  'Papua New Guinea': 0,
#  'Zimbabwe': 0,
#  'Ivory Coast': 3,
#  'Spain': 21,
#  'Taiwan': 0,
#  'Jamaica': 0,
#  'Albania': 0,
#  'Liberia': 0,
#  'Georgia': 0,
#  'Malawi': 0,
#  'Netherlands': 0,
#  'Latvia': 0}
